# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user\appdata\roaming\python\python313\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\user\appdata\roaming\python\python313\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\user\appdata\roaming\python\python313\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from nltk) (2026.2.19)
# Requirement already satisfied: tqdm in c:\users\user\appdata\roaming\python\python313\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus= """ Hello welcome, to krish naik's NLP tutorials.
please so watch the entire course! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#  Hello welcome, to krish naik's NLP tutorials.
# please so watch the entire course! to become expert in NLP.

# %%
## tokenisation 
## sentence to para
from nltk.tokenize import sent_tokenize

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
document=sent_tokenize(corpus)

# %%
document
# Out:
# [" Hello welcome, to krish naik's NLP tutorials.",
#  'please so watch the entire course!',
#  'to become expert in NLP.']

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'krish',
#  'naik',
#  "'s",
#  'NLP',
#  'tutorials',
#  '.',
#  'please',
#  'so',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
TBWtokenizer=TreebankWordTokenizer()
TBWtokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'krish',
#  'naik',
#  "'s",
#  'NLP',
#  'tutorials.',
#  'please',
#  'so',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
